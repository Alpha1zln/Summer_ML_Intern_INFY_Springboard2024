# %%
import pandas as pd

# %% [markdown]
# **tmdb(3rd_milestone_week_5)TASK_1_Test_data_Cleaning.ipynb**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/intern sy/infy_2024_ML/official/official info/milestone new/test_tmdb_no_revenue.csv'

# %%
df = pd.read_csv(file_path)

df.head()
# Out:
#    movie_id    budget                                   genres  \
# 0     41210  19000000                   Comedy, Romance, Drama
# 1       281  42000000  Crime, Drama, Science Fiction, Thriller
# 2     16290  20000000              Comedy, Documentary, Action
# 3     25239     80000                         Horror, Thriller
# 4      2294  22000000                                   Comedy
#
#                                            movie_url    imdb_id  \
# 0                                                NaN  tt0889573
# 1                        http://www.strange-days.com  tt0114558
# 2                                                NaN  tt1116184
# 3              http://www.ispitonyourgravemovies.com  tt0077713
# 4  https://www.miramax.com/movie/jay-and-silent-b...  tt0261392
#
#   original_language                     movie_title  \
# 0                en                      The Switch
# 1                en                    Strange Days
# 2                en                      Jackass 3D
# 3                en                Day of the Woman
# 4                en  Jay and Silent Bob Strike Back
#
#                                             overview  popularity  \
# 0  Kassie is a smart, fun-loving single woman who...      37.077
# 1  Former policeman Lenny Nero has moved into a m...      28.075
# 2  Johnny Knoxville, Bam Margera, Steve-O, Wee Ma...      16.325
# 3  A young, beautiful career woman rents a backwo...      27.573
# 4  When Jay and Silent Bob learn that their comic...      16.321
#
#                         poster_path  ...      production_countries  \
# 0  /lQZpZHLafAfYwogCF23lnfPQmIh.jpg  ...  United States of America
# 1  /rY5BrDRcYAKE0BYmmT66YG6Uy5Q.jpg  ...  United States of America
# 2  /rqK0MkfpWT2DpFjNzkvjHf0vxZ4.jpg  ...  United States of America
# 3  /nMCkOo26GtISoxJmpkTAJyMqBO8.jpg  ...  United States of America
# 4  /aEsAdMAhwKYFgnHHxMOknktQYKK.jpg  ...  United States of America
#
#   release_date runtime  spoken_languages    status  \
# 0   2010-05-11     101           English  Released
# 1   1995-10-13     145           English  Released
# 2   2010-10-15      99   Română, English  Released
# 3   1978-11-02     101           English  Released
# 4   2001-08-22     104           English  Released
#
#                                              tagline  \
# 0         The most unexpected comedy ever conceived.
# 1                               You Know You Want It
# 2  3 Times the Laughs. 3 Times the Stupid. 3 Time...
# 3  After it was all over... she waited... then sh...
# 4                            Hollywood had it coming
#
#                             title  \
# 0                      The Switch
# 1                    Strange Days
# 2                      Jackass 3D
# 3                Day of the Woman
# 4  Jay and Silent Bob Strike Back
#
#                                             keywords  \
# 0  new york city, pregnancy, hypochondriac, littl...
# 1  future, pornography, prostitute, police brutal...
# 2  pain, stunt, stuntman, stupidity, duringcredit...
# 3  rape, castration, revenge, gang rape, writer, ...
# 4  experiment, movie business, comic book, breaki...
#
#                                                 cast  \
# 0  Jennifer Aniston, Jason Bateman, Patrick Wilso...
# 1  Ralph Fiennes, Angela Bassett, Juliette Lewis,...
# 2  Johnny Knoxville, Bam Margera, Ryan Dunn, Stev...
# 3  Camille Keaton, Eron Tabor, Richard Pace, Anth...
# 4  Jason Mewes, Kevin Smith, Ben Affleck, Jeff An...
#
#                                                 crew
# 0  Allan Loeb, Josh Gordon, Will Speck, Ron Yerxa...
# 1  Kathryn Bigelow, James Cameron, Jay Cocks, Jam...
# 2  Jeff Tremaine, Spike Jonze, Johnny Knoxville, ...
# 3  Meir Zarchi, Meir Zarchi, Meir Zarchi, Joseph ...
# 4  Kevin Smith, Kevin Smith, Kevin Smith, Scott M...
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (1003, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_id              1003 non-null   int64
#  1   budget                1003 non-null   int64
#  2   genres                1003 non-null   object
#  3   movie_url             296 non-null    object
#  4   imdb_id               1003 non-null   object
#  5   original_language     1003 non-null   object
#  6   movie_title           1003 non-null   object
#  7   overview              1003 non-null   object
#  8   popularity            1003 non-null   float64
#  9   poster_path           1003 non-null   object
#  10  production_companies  995 non-null    object
#  11  production_countries  1001 non-null   object
#  12  release_date          1003 non-null   object
#  13  runtime               1003 non-null   int64
#  14  spoken_languages      1003 non-null   object
#  15  status                1003 non-null   object
#  16  tagline               950 non-null    object
#  17  title                 1003 non-null   object
#  18  keywords              976 non-null    object
#  19  cast                  1003 non-null   object
#  20  crew                  1003 non-null   object
# dtypes: float64(1), int64(3), object(17)
# memory usage: 164.7+ KB

# %% [markdown]
# QUES 1 :
# 1) change column names
#
# homepage - movie_url
# original_title - movie_title

# %%
#  ANS 1 - CODE :

# Change column names
df.rename(columns={'homepage': 'movie_url', 'original_title': 'movie_title'}, inplace=True)

# %%
# ANS 1 - OUTPUT :
df.head()
# Out:
#    movie_id    budget                                   genres  \
# 0     41210  19000000                   Comedy, Romance, Drama
# 1       281  42000000  Crime, Drama, Science Fiction, Thriller
# 2     16290  20000000              Comedy, Documentary, Action
# 3     25239     80000                         Horror, Thriller
# 4      2294  22000000                                   Comedy
#
#                                            movie_url    imdb_id  \
# 0                                                NaN  tt0889573
# 1                        http://www.strange-days.com  tt0114558
# 2                                                NaN  tt1116184
# 3              http://www.ispitonyourgravemovies.com  tt0077713
# 4  https://www.miramax.com/movie/jay-and-silent-b...  tt0261392
#
#   original_language                     movie_title  \
# 0                en                      The Switch
# 1                en                    Strange Days
# 2                en                      Jackass 3D
# 3                en                Day of the Woman
# 4                en  Jay and Silent Bob Strike Back
#
#                                             overview  popularity  \
# 0  Kassie is a smart, fun-loving single woman who...      37.077
# 1  Former policeman Lenny Nero has moved into a m...      28.075
# 2  Johnny Knoxville, Bam Margera, Steve-O, Wee Ma...      16.325
# 3  A young, beautiful career woman rents a backwo...      27.573
# 4  When Jay and Silent Bob learn that their comic...      16.321
#
#                         poster_path  ...      production_countries  \
# 0  /lQZpZHLafAfYwogCF23lnfPQmIh.jpg  ...  United States of America
# 1  /rY5BrDRcYAKE0BYmmT66YG6Uy5Q.jpg  ...  United States of America
# 2  /rqK0MkfpWT2DpFjNzkvjHf0vxZ4.jpg  ...  United States of America
# 3  /nMCkOo26GtISoxJmpkTAJyMqBO8.jpg  ...  United States of America
# 4  /aEsAdMAhwKYFgnHHxMOknktQYKK.jpg  ...  United States of America
#
#   release_date runtime  spoken_languages    status  \
# 0   2010-05-11     101           English  Released
# 1   1995-10-13     145           English  Released
# 2   2010-10-15      99   Română, English  Released
# 3   1978-11-02     101           English  Released
# 4   2001-08-22     104           English  Released
#
#                                              tagline  \
# 0         The most unexpected comedy ever conceived.
# 1                               You Know You Want It
# 2  3 Times the Laughs. 3 Times the Stupid. 3 Time...
# 3  After it was all over... she waited... then sh...
# 4                            Hollywood had it coming
#
#                             title  \
# 0                      The Switch
# 1                    Strange Days
# 2                      Jackass 3D
# 3                Day of the Woman
# 4  Jay and Silent Bob Strike Back
#
#                                             keywords  \
# 0  new york city, pregnancy, hypochondriac, littl...
# 1  future, pornography, prostitute, police brutal...
# 2  pain, stunt, stuntman, stupidity, duringcredit...
# 3  rape, castration, revenge, gang rape, writer, ...
# 4  experiment, movie business, comic book, breaki...
#
#                                                 cast  \
# 0  Jennifer Aniston, Jason Bateman, Patrick Wilso...
# 1  Ralph Fiennes, Angela Bassett, Juliette Lewis,...
# 2  Johnny Knoxville, Bam Margera, Ryan Dunn, Stev...
# 3  Camille Keaton, Eron Tabor, Richard Pace, Anth...
# 4  Jason Mewes, Kevin Smith, Ben Affleck, Jeff An...
#
#                                                 crew
# 0  Allan Loeb, Josh Gordon, Will Speck, Ron Yerxa...
# 1  Kathryn Bigelow, James Cameron, Jay Cocks, Jam...
# 2  Jeff Tremaine, Spike Jonze, Johnny Knoxville, ...
# 3  Meir Zarchi, Meir Zarchi, Meir Zarchi, Joseph ...
# 4  Kevin Smith, Kevin Smith, Kevin Smith, Scott M...
#
# [5 rows x 21 columns]

# %% [markdown]
# QUES 2:
# 2)Finding and removing duplicate values(dataframes)

# %%
#  ANS 2 - CODE -

# PART 1 - FIND DUPLICATES -
# Find duplicates
duplicates = df[df.duplicated()]

# Print the duplicate rows
print("Duplicate Rows:")
print(duplicates)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [movie_id, budget, genres, movie_url, imdb_id, original_language, movie_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, status, tagline, title, keywords, cast, crew]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Get the indices of the duplicate rows
duplicate_indices = df[df.duplicated()].index
print("Indices of Duplicate Rows:")
print(duplicate_indices)
# Out:
# Indices of Duplicate Rows:
# Index([], dtype='int64')

# %%
# SAVE A COPY OF ORIGINAL DF WITH CHANGE COL NAMES OF 2 COLS
df_copy = df.copy()

# %%
# ANS 2 - PART 2 -

# Find and remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
# ANS 2 - PART 3 -

# NO. OF ROWS , AFTER REMOVING DUPLICATES

# Display the first few rows of the modified DataFrame to verify changes
df.shape
# Out:
# (1003, 21)

# %%
# ANS 2 - PART 4
# duplicate rows removed = 4007-3973 = 34 rows

# %%
df.head(2)
# Out:
#    movie_id    budget                                   genres  \
# 0     41210  19000000                   Comedy, Romance, Drama
# 1       281  42000000  Crime, Drama, Science Fiction, Thriller
#
#                      movie_url    imdb_id original_language   movie_title  \
# 0                          NaN  tt0889573                en    The Switch
# 1  http://www.strange-days.com  tt0114558                en  Strange Days
#
#                                             overview  popularity  \
# 0  Kassie is a smart, fun-loving single woman who...      37.077
# 1  Former policeman Lenny Nero has moved into a m...      28.075
#
#                         poster_path  ...      production_countries  \
# 0  /lQZpZHLafAfYwogCF23lnfPQmIh.jpg  ...  United States of America
# 1  /rY5BrDRcYAKE0BYmmT66YG6Uy5Q.jpg  ...  United States of America
#
#   release_date runtime  spoken_languages    status  \
# 0   2010-05-11     101           English  Released
# 1   1995-10-13     145           English  Released
#
#                                       tagline         title  \
# 0  The most unexpected comedy ever conceived.    The Switch
# 1                        You Know You Want It  Strange Days
#
#                                             keywords  \
# 0  new york city, pregnancy, hypochondriac, littl...
# 1  future, pornography, prostitute, police brutal...
#
#                                                 cast  \
# 0  Jennifer Aniston, Jason Bateman, Patrick Wilso...
# 1  Ralph Fiennes, Angela Bassett, Juliette Lewis,...
#
#                                                 crew
# 0  Allan Loeb, Josh Gordon, Will Speck, Ron Yerxa...
# 1  Kathryn Bigelow, James Cameron, Jay Cocks, Jam...
#
# [2 rows x 21 columns]

# %% [markdown]
# QUES 3 :
# 3) checking of any null or empty values in dataframes
# and try to fetch and add that missing data using movie id

# %%
# ANS 3 - STEPS -

# To check for null or empty values in a DataFrame and handle them, you can follow these steps:

# Identify null or empty values.
# Fetch and add missing data (if possible).
# Handle remaining missing data appropriately (e.g., filling with default values, dropping rows/columns).

# %%
# ANS 3 - STEP 1 -
# Step 1: Check for null or empty values

null_values = df.isnull().sum()
empty_values = (df == '').sum()

print("Null values in each column:")
print(null_values)

print("\nEmpty values in each column:")
print(empty_values)
# Out:
# Null values in each column:
# movie_id                  0
# budget                    0
# genres                    0
# movie_url               707
# imdb_id                   0
# original_language         0
# movie_title               0
# overview                  0
# popularity                0
# poster_path               0
# production_companies      8
# production_countries      2
# release_date              0
# runtime                   0
# spoken_languages          0
# status                    0
# tagline                  53
# title                     0
# keywords                 27
# cast                      0
# crew                      0
# dtype: int64
#
# Empty values in each column:
# movie_id                0
# budget                  0
# genres                  0
# movie_url               0
# imdb_id                 0
# original_language       0
# movie_title             0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# keywords                0
# cast                    0
# crew                    0
# dtype: int64

# %%
# NULL VALUES -
# movie_url               707
# production_companies      8
# production_countries      2
# tagline                  53
# keywords                 27

# TOTAL - 5 COLS HAVING NULL VALUES

# AND NO EMPTY COLS

# %%
# ANS 3 - STEP 2 -
# CODE TO FETCH 2 COLS NULL VALUES FROM TMDB SITE USING API
# Fills missing movie_url and movie_title using the TMDB API.


import pandas as pd
import requests

# Function to fetch movie details from TMDB using IMDb ID
def fetch_movie_details(imdb_id, api_key):
    url = f"https://api.themoviedb.org/3/find/{imdb_id}"
    params = {
        'api_key': api_key,
        'external_source': 'imdb_id'
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        if data['movie_results']:
            movie = data['movie_results'][0]
            movie_url = f"https://www.themoviedb.org/movie/{movie['id']}"
            movie_title = movie['title']
            return movie_url, movie_title
    return None, None



# Your TMDB API key
api_key = '5abf4d126acc10d018d17b034dd7bb40'

# Iterate over the rows to fill missing movie_url and movie_title
for index, row in df.iterrows():
    if pd.isnull(row['movie_url']) or pd.isnull(row['movie_title']) or row['movie_url'] == '' or row['movie_title'] == '':
        imdb_id = row['imdb_id']
        movie_url, movie_title = fetch_movie_details(imdb_id, api_key)
        if movie_url:
            df.at[index, 'movie_url'] = movie_url
        if movie_title:
            df.at[index, 'movie_title'] = movie_title

# %%
df_cleaned_file_with_fetched_values = df.copy()

# Display the first few rows of the modified DataFrame to verify changes
df.head(2)
# Out:
#    movie_id    budget                                   genres  \
# 0     41210  19000000                   Comedy, Romance, Drama
# 1       281  42000000  Crime, Drama, Science Fiction, Thriller
#
#                                 movie_url    imdb_id original_language  \
# 0  https://www.themoviedb.org/movie/41210  tt0889573                en
# 1             http://www.strange-days.com  tt0114558                en
#
#     movie_title                                           overview  \
# 0    The Switch  Kassie is a smart, fun-loving single woman who...
# 1  Strange Days  Former policeman Lenny Nero has moved into a m...
#
#    popularity                       poster_path  ...  \
# 0      37.077  /lQZpZHLafAfYwogCF23lnfPQmIh.jpg  ...
# 1      28.075  /rY5BrDRcYAKE0BYmmT66YG6Uy5Q.jpg  ...
#
#        production_countries release_date runtime  spoken_languages    status  \
# 0  United States of America   2010-05-11     101           English  Released
# 1  United States of America   1995-10-13     145           English  Released
#
#                                       tagline         title  \
# 0  The most unexpected comedy ever conceived.    The Switch
# 1                        You Know You Want It  Strange Days
#
#                                             keywords  \
# 0  new york city, pregnancy, hypochondriac, littl...
# 1  future, pornography, prostitute, police brutal...
#
#                                                 cast  \
# 0  Jennifer Aniston, Jason Bateman, Patrick Wilso...
# 1  Ralph Fiennes, Angela Bassett, Juliette Lewis,...
#
#                                                 crew
# 0  Allan Loeb, Josh Gordon, Will Speck, Ron Yerxa...
# 1  Kathryn Bigelow, James Cameron, Jay Cocks, Jam...
#
# [2 rows x 21 columns]

# %%
df.shape
# Out:
# (1003, 21)

# %%
df_cleaned_file_with_fetched_values.shape
# Out:
# (1003, 21)

# %%
# ANS 3 - STEP 3 -
# Check for null values after fixing 2 cols = movie_url and movie_title

null_values = df.isnull().sum()

print("Null values in each column:")
print(null_values)
# Out:
# Null values in each column:
# movie_id                 0
# budget                   0
# genres                   0
# movie_url                0
# imdb_id                  0
# original_language        0
# movie_title              0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     8
# production_countries     2
# release_date             0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                 53
# title                    0
# keywords                27
# cast                     0
# crew                     0
# dtype: int64

# %%
# ANS 3 - step 4 - RESULT  -
# movie_url and movie_title COLS have 'NO' null values now
# movie_url                 0
# movie_title               0

# %%
# ANS 3 - STEP 5 -
# "REST OF THE COLS" = NULL VALUES HANDLE

# Fills missing numerical values with the column's mean and categorical values with the column's mode.
# # Handling missing values for the rest of the columns


for column in df.columns:
    if df[column].isnull().sum() > 0 or (df[column] == '').sum() > 0:
        if df[column].dtype in ['float64', 'int64']:  # Numerical column
            mean_value = df[column].mean()
            df[column].fillna(mean_value, inplace=True)
            df[column].replace('', mean_value, inplace=True)
        else:  # Categorical column
            mode_value = df[column].mode()[0]
            df[column].fillna(mode_value, inplace=True)
            df[column].replace('', mode_value, inplace=True)


df.shape
# Out:
# (1003, 21)

# %%
# ANS 3 - STEP 6 -
# CHECK NULL VALUES COLS AGAIN TO GET FINAL RESULT

null_values = df.isnull().sum()

print("Null values in each column:")
print(null_values)
# Out:
# Null values in each column:
# movie_id                0
# budget                  0
# genres                  0
# movie_url               0
# imdb_id                 0
# original_language       0
# movie_title             0
# overview                0
# popularity              0
# poster_path             0
# production_companies    0
# production_countries    0
# release_date            0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# keywords                0
# cast                    0
# crew                    0
# dtype: int64

# %%
# ANS 3 - STEP 7 -
# FINAL RESULT :

# NOW, # NOW , FROM ABOVE NULL VALUES OUTPUT , IT IS CLEAR, THAT NULL  VALUES ARE HANDLED AND NO NULL VALUES ARE PRESENT NOW

# %%
# # ANS 4 - STEP 1 -
# # CHECK HOW MANY COLS HAVE REVENUE = 0

# # Check how many rows have revenue as 0
# zero_revenue_count = (df['revenue'] == 0).sum()
# print(f"Number of rows with revenue = 0 are : {zero_revenue_count}")

# %% [markdown]
# QUES 5 -
#
# 5) finally convert that processed output(dataframes) to csv format

# %%
# ANS 5 -

# STEP 1 : SAVE FINAL DF into a new df, df_processed.
df_processed = df.copy()

# %%
df_processed.head(2)
# Out:
#    movie_id    budget                                   genres  \
# 0     41210  19000000                   Comedy, Romance, Drama
# 1       281  42000000  Crime, Drama, Science Fiction, Thriller
#
#                                 movie_url    imdb_id original_language  \
# 0  https://www.themoviedb.org/movie/41210  tt0889573                en
# 1             http://www.strange-days.com  tt0114558                en
#
#     movie_title                                           overview  \
# 0    The Switch  Kassie is a smart, fun-loving single woman who...
# 1  Strange Days  Former policeman Lenny Nero has moved into a m...
#
#    popularity                       poster_path  ...  \
# 0      37.077  /lQZpZHLafAfYwogCF23lnfPQmIh.jpg  ...
# 1      28.075  /rY5BrDRcYAKE0BYmmT66YG6Uy5Q.jpg  ...
#
#        production_countries release_date runtime  spoken_languages    status  \
# 0  United States of America   2010-05-11     101           English  Released
# 1  United States of America   1995-10-13     145           English  Released
#
#                                       tagline         title  \
# 0  The most unexpected comedy ever conceived.    The Switch
# 1                        You Know You Want It  Strange Days
#
#                                             keywords  \
# 0  new york city, pregnancy, hypochondriac, littl...
# 1  future, pornography, prostitute, police brutal...
#
#                                                 cast  \
# 0  Jennifer Aniston, Jason Bateman, Patrick Wilso...
# 1  Ralph Fiennes, Angela Bassett, Juliette Lewis,...
#
#                                                 crew
# 0  Allan Loeb, Josh Gordon, Will Speck, Ron Yerxa...
# 1  Kathryn Bigelow, James Cameron, Jay Cocks, Jam...
#
# [2 rows x 21 columns]

# %%
df_processed.shape
# Out:
# (1003, 21)

# %%
# STEP 2 -
# CONVERT DF TO CSV

# Save the processed data to a CSV file
df_processed.to_csv('test_df_cleaned.csv', index=False)


# STEP 3 -
# DOWNLOAD LIBRARY FOR FILES
from google.colab import files

# IF NOT COLAB, USE other CODE -

# %%
# STEP 4 -
#  DOWNLOAD CSV

#  Download the CSV file
files.download('test_df_cleaned.csv')

# %%
# MILESTONE 3 - part 1 -  COMPLETED
